# %%
import os
import math
import csv
import numpy as np
import rasterio
from rasterio.windows import Window
from rasterio.transform import rowcol
from rasterio import features
import geopandas as gpd
from shapely.geometry import box

# %%
# Use your own path!!
BIG_TIF = "/Users/hexinyi/Desktop/temporary/S2_RGB8_2024-02-01_2024-10-31_RGB8.tif"                 
POLY_VEC = "/Users/hexinyi/Desktop/temporary/filterlot.gpkg"                 
ID_FIELD = "OBJECTID"                     

OUT_DIR = "/Users/hexinyi/Downloads/RGBtest4"             
PATCH_SMALL = 256                        
PATCH_LARGE = 512                    
MARGIN_PX = 20                           
TILE_OVERLAP = 256                        

PAD_TO_FULL = False                     

os.makedirs(OUT_DIR, exist_ok=True)

# open big tif
src = rasterio.open(BIG_TIF)
r_crs = src.crs
r_transform = src.transform
r_height, r_width = src.height, src.width
profile_base = src.profile


gdf = gpd.read_file(POLY_VEC)
if gdf.crs is None:
    raise ValueError("No CRS")
if gdf.crs != r_crs:
    gdf = gdf.to_crs(r_crs)


def geom_bbox_px(geom):
    minx, miny, maxx, maxy = geom.bounds  
    r0, c0 = rowcol(r_transform, minx, maxy) 
    r1, c1 = rowcol(r_transform, maxx, miny)
    ymin, ymax = min(r0, r1), max(r0, r1)
    xmin, xmax = min(c0, c1), max(c0, c1)

    xmin -= MARGIN_PX
    ymin -= MARGIN_PX
    xmax += MARGIN_PX
    ymax += MARGIN_PX

    xmin = max(0, xmin)
    ymin = max(0, ymin)
    xmax = min(r_width,  xmax)
    ymax = min(r_height, ymax)

    w = max(0, xmax - xmin)
    h = max(0, ymax - ymin)
    return int(xmin), int(ymin), int(w), int(h)

def write_patch(window, out_path):
    win_w = int(window.width)
    win_h = int(window.height)
    data = src.read(window=window)  # (bands, h, w)

    if PAD_TO_FULL:
        target_w, target_h = window.width, window.height
        if isinstance(target_w, float): target_w = int(target_w)
        if isinstance(target_h, float): target_h = int(target_h)
        pad_w = target_w
        pad_h = target_h
        if data.shape[1] != pad_h or data.shape[2] != pad_w:
            canvas = np.zeros((data.shape[0], pad_h, pad_w), dtype=data.dtype)
            canvas[:, :data.shape[1], :data.shape[2]] = data
            data = canvas
            win_w, win_h = pad_w, pad_h

    transform = rasterio.windows.transform(window, r_transform)
    profile = profile_base.copy()
    profile.update({
        "height": win_h,
        "width":  win_w,
        "transform": transform
    })
    with rasterio.open(out_path, "w", **profile) as dst:
        dst.write(data)

manifest_path = os.path.join(OUT_DIR, "manifest.csv")
with open(manifest_path, "w", newline="") as fcsv:
    writer = csv.writer(fcsv)
    writer.writerow(["patch_path","poly_id","x_off","y_off","width","height",
                     "patch_size","tile_idx"])

    for idx, feat in gdf.iterrows():
        geom = feat.geometry
        poly_id = str(feat.get(ID_FIELD, f"poly_{idx}"))

        xmin, ymin, bw, bh = geom_bbox_px(geom)
        if bw == 0 or bh == 0:
            continue  

        max_dim = max(bw, bh)

        if max_dim <= PATCH_SMALL:
            psize = PATCH_SMALL
            x_off = max(0, min(xmin + bw//2 - psize//2, r_width  - psize))
            y_off = max(0, min(ymin + bh//2 - psize//2, r_height - psize))
            win_w = min(psize, r_width  - x_off)
            win_h = min(psize, r_height - y_off)
            window = Window(x_off, y_off, win_w, win_h)
            out_name = os.path.join(OUT_DIR, 
                                    f"patch_{poly_id}_S_{x_off}_{y_off}.tif")
            write_patch(window, out_name)
            writer.writerow([out_name, poly_id, x_off, y_off, 
                             win_w, win_h, psize, 0])

        elif max_dim <= PATCH_LARGE:
            psize = PATCH_LARGE
            x_off = max(0, min(xmin + bw//2 - psize//2, r_width  - psize))
            y_off = max(0, min(ymin + bh//2 - psize//2, r_height - psize))
            win_w = min(psize, r_width  - x_off)
            win_h = min(psize, r_height - y_off)
            window = Window(x_off, y_off, win_w, win_h)
            out_name = os.path.join(OUT_DIR, 
                                    f"patch_{poly_id}_L_{x_off}_{y_off}.tif")
            write_patch(window, out_name)
            writer.writerow([out_name, poly_id, x_off, y_off, 
                             win_w, win_h, psize, 0])

        else:
            psize = PATCH_LARGE
            stride = psize - TILE_OVERLAP
            tiles = []
            for y_off in range(ymin, ymin + bh, stride):
                for x_off in range(xmin, xmin + bw, stride):
                    x_off_clamp = max(0, min(x_off, r_width  - psize))
                    y_off_clamp = max(0, min(y_off, r_height - psize))
                    win_w = min(psize, r_width  - x_off_clamp)
                    win_h = min(psize, r_height - y_off_clamp)
                    tiles.append((x_off_clamp, y_off_clamp, win_w, win_h))

            seen = set()
            unique_tiles = []
            for t in tiles:
                key = (t[0], t[1], t[2], t[3])
                if key not in seen:
                    seen.add(key)
                    unique_tiles.append(t)

            for ti, (x_off, y_off, win_w, win_h) in enumerate(unique_tiles):
                window = Window(x_off, y_off, win_w, win_h)
                out_name = os.path.join(OUT_DIR, 
                            f"patch_{poly_id}_T{ti:02d}_{x_off}_{y_off}.tif")
                write_patch(window, out_name)
                writer.writerow([out_name, poly_id, x_off, y_off, 
                                 win_w, win_h, psize, ti])

src.close()
print(f"✅ Complete。ouput path: {OUT_DIR}\n📄 manifest: {manifest_path}")
# Out:
# ✅ Complete。ouput path: /Users/hexinyi/Downloads/RGBtest3
# 📄 manifest: /Users/hexinyi/Downloads/RGBtest3/manifest.csv

# %%
# add ID
import json
import os
from glob import glob

def add_polygon_ids_to_folder(folder_path, save_folder=None):
    if save_folder is None:
        save_folder = os.path.join(folder_path, "withID")
    os.makedirs(save_folder, exist_ok=True)

    json_files = glob(os.path.join(folder_path, "*.json"))
    print(f"find {len(json_files)} .JSON ")

    for json_path in json_files:
        with open(json_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        for idx, shape in enumerate(data.get("shapes", [])):
            shape["polygon_id"] = idx

        filename = os.path.basename(json_path)
        save_path = os.path.join(save_folder, filename)

        with open(save_path, "w", encoding="utf-8") as f:
            json.dump(data, f, indent=2, ensure_ascii=False)

        print(f"complete ✅ {filename} → {save_path}")

    print("Complete all ✅")

# Use your own path
add_polygon_ids_to_folder("/Users/hexinyi/Desktop/9.17")
# Out:
# find 89 .JSON
# complete ✅ patch_1402030_S_1525_1997.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402030_S_1525_1997.json
# complete ✅ patch_1402002_S_1927_3040.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402002_S_1927_3040.json
# complete ✅ patch_1402059_S_1131_1230.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402059_S_1131_1230.json
# complete ✅ patch_1402216_S_2018_1739.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402216_S_2018_1739.json
# complete ✅ patch_1402024_S_1231_2377.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402024_S_1231_2377.json
# complete ✅ patch_1402087_S_2022_1940.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402087_S_2022_1940.json
# complete ✅ patch_1401983_S_769_2151.json → /Users/hexinyi/Desktop/9.17/withID/patch_1401983_S_769_2151.json
# complete ✅ patch_1402364_S_2550_1600.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402364_S_2550_1600.json
# complete ✅ patch_1402034_S_988_2142.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402034_S_988_2142.json
# complete ✅ patch_1402035_S_1062_2042.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402035_S_1062_2042.json
# complete ✅ patch_1402432_S_1041_2369.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402432_S_1041_2369.json
# complete ✅ patch_1402062_S_2199_1724.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402062_S_2199_1724.json
# complete ✅ patch_1402192_S_1642_1328.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402192_S_1642_1328.json
# complete ✅ patch_1402210_S_1245_1439.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402210_S_1245_1439.json
# complete ✅ patch_70250_L_1549_941.json → /Users/hexinyi/Desktop/9.17/withID/patch_70250_L_1549_941.json
# complete ✅ patch_1402283_S_1259_2020.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402283_S_1259_2020.json
# complete ✅ patch_1402287_S_1484_2162.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402287_S_1484_2162.json
# complete ✅ patch_1402357_S_1999_1719.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402357_S_1999_1719.json
# complete ✅ patch_1402358_S_2028_1728.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402358_S_2028_1728.json
# complete ✅ patch_1402041_S_902_1944.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402041_S_902_1944.json
# complete ✅ patch_1402039_S_797_2026.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402039_S_797_2026.json
# complete ✅ patch_1402037_S_1560_1833.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402037_S_1560_1833.json
# complete ✅ patch_1402063_S_2061_1765.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402063_S_2061_1765.json
# complete ✅ patch_1402021_S_961_2452.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402021_S_961_2452.json
# complete ✅ patch_1402369_S_940_1824.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402369_S_940_1824.json
# complete ✅ patch_1401957_S_1827_3124.json → /Users/hexinyi/Desktop/9.17/withID/patch_1401957_S_1827_3124.json
# complete ✅ patch_1402061_S_2129_1755.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402061_S_2129_1755.json
# complete ✅ patch_1402060_S_2208_1754.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402060_S_2208_1754.json
# complete ✅ patch_1401989_S_1032_1693.json → /Users/hexinyi/Desktop/9.17/withID/patch_1401989_S_1032_1693.json
# complete ✅ patch_1402355_S_2167_1451.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402355_S_2167_1451.json
# complete ✅ patch_1402215_S_2194_1898.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402215_S_2194_1898.json
# complete ✅ patch_1402290_S_860_2061.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402290_S_860_2061.json
# complete ✅ patch_1402227_S_1933_1760.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402227_S_1933_1760.json
# complete ✅ patch_1402218_S_2347_1464.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402218_S_2347_1464.json
# complete ✅ patch_1402426_S_1077_1717.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402426_S_1077_1717.json
# complete ✅ patch_1402003_S_1636_2814.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402003_S_1636_2814.json
# complete ✅ patch_1402078_L_2560_1751.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402078_L_2560_1751.json
# complete ✅ patch_1402187_S_2298_1955.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402187_S_2298_1955.json
# complete ✅ patch_69910_S_1806_1008.json → /Users/hexinyi/Desktop/9.17/withID/patch_69910_S_1806_1008.json
# complete ✅ patch_1402028_S_1435_2278.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402028_S_1435_2278.json
# complete ✅ patch_1402336_S_2098_1059.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402336_S_2098_1059.json
# complete ✅ patch_1402173_S_2112_1707.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402173_S_2112_1707.json
# complete ✅ patch_1402349_S_2235_1915.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402349_S_2235_1915.json
# complete ✅ patch_1402348_S_2299_1861.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402348_S_2299_1861.json
# complete ✅ patch_1402183_S_2136_1262.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402183_S_2136_1262.json
# complete ✅ patch_1402250_S_1895_3166.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402250_S_1895_3166.json
# complete ✅ patch_1402031_S_1570_2025.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402031_S_1570_2025.json
# complete ✅ patch_1402425_S_1205_1797.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402425_S_1205_1797.json
# complete ✅ patch_48066_S_2133_917.json → /Users/hexinyi/Desktop/9.17/withID/patch_48066_S_2133_917.json
# complete ✅ patch_1401981_S_1537_2319.json → /Users/hexinyi/Desktop/9.17/withID/patch_1401981_S_1537_2319.json
# complete ✅ patch_1402409_S_1619_2992.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402409_S_1619_2992.json
# complete ✅ patch_1402244_S_2146_1912.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402244_S_2146_1912.json
# complete ✅ patch_1402214_S_2223_1806.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402214_S_2223_1806.json
# complete ✅ patch_1402191_S_1458_1139.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402191_S_1458_1139.json
# complete ✅ patch_1402354_S_2235_1461.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402354_S_2235_1461.json
# complete ✅ patch_1401998_L_2618_2632.json → /Users/hexinyi/Desktop/9.17/withID/patch_1401998_L_2618_2632.json
# complete ✅ patch_1401959_L_1164_3155.json → /Users/hexinyi/Desktop/9.17/withID/patch_1401959_L_1164_3155.json
# complete ✅ patch_1402064_S_2081_1819.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402064_S_2081_1819.json
# complete ✅ patch_1402032_S_908_2286.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402032_S_908_2286.json
# complete ✅ patch_1402266_S_1587_2226.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402266_S_1587_2226.json
# complete ✅ patch_1402000_S_2035_2147.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402000_S_2035_2147.json
# complete ✅ patch_1402036_S_1100_2066.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402036_S_1100_2066.json
# complete ✅ patch_1401958_L_1636_2883.json → /Users/hexinyi/Desktop/9.17/withID/patch_1401958_L_1636_2883.json
# complete ✅ patch_68564_S_1539_938.json → /Users/hexinyi/Desktop/9.17/withID/patch_68564_S_1539_938.json
# complete ✅ patch_1402172_S_2025_1846.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402172_S_2025_1846.json
# complete ✅ patch_1402196_S_2262_1843.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402196_S_2262_1843.json
# complete ✅ patch_1402193_S_1582_1348.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402193_S_1582_1348.json
# complete ✅ patch_1401999_L_2302_2817.json → /Users/hexinyi/Desktop/9.17/withID/patch_1401999_L_2302_2817.json
# complete ✅ patch_1402344_S_2301_1264.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402344_S_2301_1264.json
# complete ✅ patch_1402362_S_1983_1640.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402362_S_1983_1640.json
# complete ✅ patch_1402033_S_973_2326.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402033_S_973_2326.json
# complete ✅ patch_1402293_S_1128_2229.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402293_S_1128_2229.json
# complete ✅ patch_1402040_S_789_1871.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402040_S_789_1871.json
# complete ✅ patch_1402023_S_1165_2482.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402023_S_1165_2482.json
# complete ✅ patch_1401982_S_1618_2268.json → /Users/hexinyi/Desktop/9.17/withID/patch_1401982_S_1618_2268.json
# complete ✅ patch_1402253_S_2606_3107.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402253_S_2606_3107.json
# complete ✅ patch_1402022_S_1160_2653.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402022_S_1160_2653.json
# complete ✅ patch_1402042_S_1060_2186.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402042_S_1060_2186.json
# complete ✅ patch_1402052_S_1552_2949.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402052_S_1552_2949.json
# complete ✅ patch_1402295_S_1052_1890.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402295_S_1052_1890.json
# complete ✅ patch_1402267_S_850_2211.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402267_S_850_2211.json
# complete ✅ patch_1402007_S_1458_3018.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402007_S_1458_3018.json
# complete ✅ patch_1402010_L_900_3036.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402010_L_900_3036.json
# complete ✅ patch_1402043_S_1119_1933.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402043_S_1119_1933.json
# complete ✅ patch_1402217_S_2003_1759.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402217_S_2003_1759.json
# complete ✅ patch_1402427_S_1137_1754.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402427_S_1137_1754.json
# complete ✅ patch_1402029_S_1439_2134.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402029_S_1439_2134.json
# complete ✅ patch_1402292_S_1327_1873.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402292_S_1327_1873.json
# complete ✅ patch_1402245_S_2172_1866.json → /Users/hexinyi/Desktop/9.17/withID/patch_1402245_S_2172_1866.json
# Complete all ✅
