# %%
import os, re
from pathlib import Path
import geopandas as gpd
import pandas as pd

try:
    import pyogrio
    HAS_PYOGRIO = True
except Exception:
    HAS_PYOGRIO = False


# ===================== 配置部分 =====================
PATCH_DIR = Path("/Users/lin/Desktop/RGB4")          # 你的 patch 文件夹路径
IN_GPKG = Path("/Users/lin/Downloads/S2_test/fiter.gpkg")
LAYER_NAME = "lot"                         # GPKG 图层名
OUT_DIR = Path("/Users/lin/Desktop/per_target_gpkg")    # 输出文件夹
ID_COL = "ObJECTID"                                     # GPKG 里代表目标ID的列名
# ====================================================

def guess_id_col(cols, user_id=None):
    if user_id and user_id in cols: return user_id
    for c in ["objectID","OBJECTID","ObjectID","object_id","id","ID"]:
        if c in cols: return c
    raise ValueError(f"未找到 objectID 列，可选列有：{list(cols)}")

def extract_id_from_name(name: str):
    base = os.path.basename(name)
    m = re.match(r"patch_([^_]+)_", base)
    return m.group(1) if m else None

def collect_ids_from_dir(patch_dir: Path):
    exts = (".tif", ".tiff", ".png", ".jpg", ".jpeg")
    ids = []
    for p in patch_dir.iterdir():
        if p.is_file() and p.suffix.lower() in exts and "patch_" in p.name:
            oid = extract_id_from_name(p.name)
            if oid is not None:
                ids.append(str(oid))
    ids = sorted(set(ids))
    if not ids:
        raise RuntimeError("未在目录中解析到任何 objectID，请检查文件命名是否类似 patch_<ID>_*.tif")
    print(f"[INFO] 收集到 {len(ids)} 个唯一 objectID：{ids[:8]}{' ...' if len(ids)>8 else ''}")
    return ids

def sanitize_filename(s: str) -> str:
    return re.sub(r"[^0-9A-Za-z_\-]+", "_", str(s).strip()) or "unknown"

def fix_geometry_if_needed(gdf):
    if not gdf.geometry.is_valid.all():
        gdf = gdf.copy()
        gdf["geometry"] = gdf.geometry.buffer(0)
    return gdf

def export_split_by_id():
    ids = collect_ids_from_dir(PATCH_DIR)
    OUT_DIR.mkdir(parents=True, exist_ok=True)

    if HAS_PYOGRIO:
        head = pyogrio.read_dataframe(IN_GPKG, layer=LAYER_NAME, max_features=5)
        id_col = guess_id_col(head.columns, ID_COL)
        print(f"[INFO] 使用 pyogrio 流式读取，ID列={id_col}")

        for oid in ids:
            oid_safe = oid.replace("'", "''")  # 先替换单引号，防止 SQL 注入
            where = f"{id_col} = '{oid_safe}'"
            sub = pyogrio.read_dataframe(IN_GPKG, layer=LAYER_NAME, where=where)
            if sub.empty:
                print(f"[WARN] ID {oid} 未找到，跳过。")
                continue
            sub = fix_geometry_if_needed(sub)
            out_path = OUT_DIR / f"{sanitize_filename(oid)}.gpkg"
            pyogrio.write_dataframe(sub, out_path, layer="polygon", driver="GPKG")
            print(f"[OK] 写出 {out_path} (要素数={len(sub)})")
    else:
        print("[INFO] 未安装 pyogrio，使用 geopandas 一次性读取。")
        gdf = gpd.read_file(IN_GPKG, layer=LAYER_NAME)
        id_col = guess_id_col(gdf.columns, ID_COL)
        gdf[id_col] = gdf[id_col].astype(str)
        subset = gdf[gdf[id_col].isin(set(ids))].copy()
        if subset.empty:
            raise RuntimeError("筛选结果为空，未找到匹配的ID。")
        subset = fix_geometry_if_needed(subset)

        for oid, sub in subset.groupby(id_col):
            out_path = OUT_DIR / f"{sanitize_filename(oid)}.gpkg"
            sub.to_file(out_path, layer="polygon", driver="GPKG")
            print(f"[OK] 写出 {out_path} (要素数={len(sub)})")

    print("[DONE] 全部完成 ✅")


if __name__ == "__main__":
    export_split_by_id()
# Out:
# [INFO] 收集到 206 个唯一 objectID：['1920708', '1920713', '1920714', '1920715', '1920717', '1920720', '1920721', '1920722'] ...
# [INFO] 使用 pyogrio 流式读取，ID列=OBJECTID
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920708.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920713.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920714.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920715.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920717.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920720.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920721.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920722.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920723.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920724.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920725.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920726.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920727.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920728.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920729.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920730.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920731.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920732.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920733.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920734.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920735.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920736.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920737.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920738.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920739.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920740.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920741.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920742.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920743.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920744.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920745.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920746.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920747.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920748.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920749.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920750.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920751.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920752.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920753.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920754.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920755.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920756.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920757.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920758.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920759.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920760.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920762.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920763.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920764.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920765.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920766.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920767.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920768.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920769.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920770.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920771.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920772.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920776.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920777.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920778.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920780.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920781.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920782.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920783.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920785.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920786.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920787.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920788.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920789.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920790.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920791.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920792.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920793.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920795.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920796.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920797.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920799.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920800.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920801.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920802.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920803.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920805.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920806.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920807.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920808.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920810.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920811.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920813.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920814.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920818.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920819.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920821.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920824.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920825.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920827.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920829.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920831.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920832.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920833.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920835.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920837.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920838.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920839.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920840.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920841.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920842.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920844.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920845.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920846.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920847.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920848.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920849.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920850.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920851.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920852.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920853.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920854.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920855.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920856.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920857.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920858.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920859.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920860.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920861.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920862.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920863.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920864.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920865.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920866.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920868.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920869.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920870.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920871.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920872.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920873.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920874.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920875.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920876.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920877.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920878.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920879.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920880.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920881.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920882.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920883.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920884.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920885.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920886.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920887.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920888.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920889.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920890.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920891.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920892.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920893.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920894.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920895.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920896.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920897.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920898.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920899.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920900.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920903.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920905.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920906.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/1920907.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63570.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63695.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63696.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63699.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63700.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63701.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63702.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63727.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63730.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/63733.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67509.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67510.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67511.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67512.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67519.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67539.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67540.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67541.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67543.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67544.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67993.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67994.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67995.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67997.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67998.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/67999.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68000.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68001.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68002.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68003.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68004.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68005.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68006.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68007.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68008.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68009.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68010.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68011.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/68013.gpkg (要素数=1)
# [OK] 写出 /Users/lin/Desktop/per_target_gpkg/70080.gpkg (要素数=1)
# [DONE] 全部完成 ✅
